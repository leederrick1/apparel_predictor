# %%
import csv
import pandas as pd, numpy as np, scipy as s
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("combined_data.csv")

# %%
df.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  0.0     0.0
# 1  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  0.0     0.0
# 2  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  0.0     0.0
# 3  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  0.0     0.0
# 4  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  0.0     0.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  49.0
# 2             ACTIVE                   NONE  49.0
# 3             ACTIVE                   NONE  49.0
# 4             ACTIVE                   NONE  49.0
#
#                                          postal_code       t_dat   article_id  \
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...  2018-12-27  625548001.0
# 1  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...  2018-12-27  176209023.0
# 2  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...  2018-12-27  627759010.0
# 3  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...  2019-05-02  697138006.0
# 4  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...  2019-05-25  568601006.0
#
#       price  ...         department_name  index_code              index_name  \
# 0  0.044051  ...       Young Boy Outdoor           I  Children Sizes 134-170
# 1  0.035576  ...           Jacket Street           F                Menswear
# 2  0.030492  ...       Kids Girl Outdoor           H   Children Sizes 92-140
# 3  0.010153  ...  Kids Girl Jersey Fancy           H   Children Sizes 92-140
# 4  0.050831  ...                    Suit           A              Ladieswear
#
#    index_group_no index_group_name section_no      section_name  \
# 0             4.0    Baby/Children       45.0    Kids Outerwear
# 1             3.0         Menswear       31.0    Mens Outerwear
# 2             4.0    Baby/Children       45.0    Kids Outerwear
# 3             4.0    Baby/Children       76.0         Kids Girl
# 4             1.0       Ladieswear       11.0  Womens Tailoring
#
#   garment_group_no  garment_group_name  \
# 0           1007.0             Outdoor
# 1           1007.0             Outdoor
# 2           1007.0             Outdoor
# 3           1005.0        Jersey Fancy
# 4           1008.0             Dressed
#
#                                          detail_desc
# 0  Padded jacket with a detachable hood, stand-up...
# 1  Short, padded jacket with a jersey-lined hood ...
# 2  Padded parka in woven fabric with a soft, brus...
# 3  Playsuit in cotton jersey with butterfly sleev...
# 4  Fitted jacket in woven fabric with notch lapel...
#
# [5 rows x 35 columns]

# %%
small_set = df.loc[df['customer_id'].isin(['00c160fd797be9c52491373b16ec194d4edb129c57266e85e65bb9814a25490d', '0284d10c3374ded9756bd9efeff7f6c8a2f31391364102701297e67d0886035d', '073da0c6e0c8538bc435967da0251054e48217687589a32dc9260734eeecf5da','0863b92e036a35df88e1dc6eb34b161a79d63c14c15601bdf80bab2ecb4bc454'])]

# %%
small_set
# Out:
#                                                customer_id   FN  Active  \
# 93227    00c160fd797be9c52491373b16ec194d4edb129c57266e...  1.0     1.0
# 93228    00c160fd797be9c52491373b16ec194d4edb129c57266e...  1.0     1.0
# 93229    00c160fd797be9c52491373b16ec194d4edb129c57266e...  1.0     1.0
# 93230    00c160fd797be9c52491373b16ec194d4edb129c57266e...  1.0     1.0
# 93231    00c160fd797be9c52491373b16ec194d4edb129c57266e...  1.0     1.0
# ...                                                    ...  ...     ...
# 1048610  0863b92e036a35df88e1dc6eb34b161a79d63c14c15601...  0.0     0.0
# 1048611  0863b92e036a35df88e1dc6eb34b161a79d63c14c15601...  0.0     0.0
# 1048612  0863b92e036a35df88e1dc6eb34b161a79d63c14c15601...  0.0     0.0
# 1048613  0863b92e036a35df88e1dc6eb34b161a79d63c14c15601...  0.0     0.0
# 1048614  0863b92e036a35df88e1dc6eb34b161a79d63c14c15601...  0.0     0.0
#
#         club_member_status fashion_news_frequency   age  \
# 93227               ACTIVE              Regularly  24.0
# 93228               ACTIVE              Regularly  24.0
# 93229               ACTIVE              Regularly  24.0
# 93230               ACTIVE              Regularly  24.0
# 93231               ACTIVE              Regularly  24.0
# ...                    ...                    ...   ...
# 1048610             ACTIVE                   NONE  27.0
# 1048611             ACTIVE                   NONE  27.0
# 1048612             ACTIVE                   NONE  27.0
# 1048613             ACTIVE                   NONE  27.0
# 1048614             ACTIVE                   NONE  27.0
#
#                                                postal_code       t_dat  \
# 93227    ff00631c6ec7b0902cbcfde3e49dcd986efc2e3e20745b...  2018-09-26
# 93228    ff00631c6ec7b0902cbcfde3e49dcd986efc2e3e20745b...  2018-09-26
# 93229    ff00631c6ec7b0902cbcfde3e49dcd986efc2e3e20745b...  2018-09-26
# 93230    ff00631c6ec7b0902cbcfde3e49dcd986efc2e3e20745b...  2018-09-26
# 93231    ff00631c6ec7b0902cbcfde3e49dcd986efc2e3e20745b...  2018-09-26
# ...                                                    ...         ...
# 1048610  bb3bdf0dcd8677549584823cc95f67b8aafb547d941500...  2020-08-06
# 1048611  bb3bdf0dcd8677549584823cc95f67b8aafb547d941500...  2020-08-06
# 1048612  bb3bdf0dcd8677549584823cc95f67b8aafb547d941500...  2020-08-06
# 1048613  bb3bdf0dcd8677549584823cc95f67b8aafb547d941500...  2020-08-06
# 1048614  bb3bdf0dcd8677549584823cc95f67b8aafb547d941500...  2020-08-06
#
#           article_id     price  ...      department_name  index_code  \
# 93227    564334002.0  0.025407  ...  Expressive Lingerie           B
# 93228    613246004.0  0.042356  ...              Trouser           A
# 93229    501820025.0  0.016932  ...        Tops Knitwear           D
# 93230    521302001.0  0.038966  ...             Knitwear           A
# 93231    448509009.0  0.020322  ...             Trousers           D
# ...              ...       ...  ...                  ...         ...
# 1048610  831777004.0  0.011847  ...               Blouse           A
# 1048611  834383002.0  0.042356  ...                Dress           A
# 1048612  714026020.0  0.025407  ...          Trouser S&T           F
# 1048613  714026020.0  0.025407  ...          Trouser S&T           F
# 1048614  892337003.0  0.101678  ...          Trouser S&T           F
#
#                index_name  index_group_no index_group_name section_no  \
# 93227    Lingeries/Tights             1.0       Ladieswear       61.0
# 93228          Ladieswear             1.0       Ladieswear       15.0
# 93229             Divided             2.0          Divided       53.0
# 93230          Ladieswear             1.0       Ladieswear       15.0
# 93231             Divided             2.0          Divided       53.0
# ...                   ...             ...              ...        ...
# 1048610        Ladieswear             1.0       Ladieswear       15.0
# 1048611        Ladieswear             1.0       Ladieswear       15.0
# 1048612          Menswear             3.0         Menswear       23.0
# 1048613          Menswear             3.0         Menswear       23.0
# 1048614          Menswear             3.0         Menswear       23.0
#
#                        section_name garment_group_no  garment_group_name  \
# 93227               Womens Lingerie           1017.0   Under-, Nightwear
# 93228    Womens Everyday Collection           1009.0            Trousers
# 93229            Divided Collection           1003.0            Knitwear
# 93230    Womens Everyday Collection           1003.0            Knitwear
# 93231            Divided Collection           1009.0            Trousers
# ...                             ...              ...                 ...
# 1048610  Womens Everyday Collection           1010.0             Blouses
# 1048611  Womens Everyday Collection           1013.0      Dresses Ladies
# 1048612       Men Suits & Tailoring           1009.0            Trousers
# 1048613       Men Suits & Tailoring           1009.0            Trousers
# 1048614       Men Suits & Tailoring           1009.0            Trousers
#
#                                                detail_desc
# 93227    Balconette lace bra with underwired, moulded, ...
# 93228    5-pocket jeans in washed superstretch denim wi...
# 93229    Jumper in a soft knit with a slightly wider ne...
# 93230    Wide jumper in a soft rib knit containing some...
# 93231    5-pocket, ankle-length jeans in washed, sturdy...
# ...                                                    ...
# 1048610  Top in a softly draping weave with a V-neck fr...
# 1048611  Short, sleeveless dress in sturdy satin with a...
# 1048612  Suit trousers in woven fabric with a concealed...
# 1048613  Suit trousers in woven fabric with a concealed...
# 1048614  Suit trousers in superstretch fabric made from...
#
# [729 rows x 35 columns]

# %%
small_set.to_csv("smallset.csv",index=False)
